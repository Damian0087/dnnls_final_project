# %% [markdown]
# # BI-DIRECTIONAL METRICS TABLE
# ![bidirectional metrics.PNG](data:image/png;base64,...)

# %% [markdown]
# # BI-DIRECTIONAL PLOTS
# ![bidirectional plots.PNG](data:image/png;base64,...)
